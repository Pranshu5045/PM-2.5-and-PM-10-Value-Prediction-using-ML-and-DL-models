# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('aurangabad_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1021/1021 - 9s - loss: 0.0178 - 9s/epoch - 9ms/step
# Epoch 2/100
# 1021/1021 - 5s - loss: 0.0016 - 5s/epoch - 5ms/step
# Epoch 3/100
# 1021/1021 - 5s - loss: 0.0012 - 5s/epoch - 5ms/step
# Epoch 4/100
# 1021/1021 - 5s - loss: 0.0011 - 5s/epoch - 5ms/step
# Epoch 5/100
# 1021/1021 - 5s - loss: 9.7043e-04 - 5s/epoch - 5ms/step
# Epoch 6/100
# 1021/1021 - 5s - loss: 6.7067e-04 - 5s/epoch - 5ms/step
# Epoch 7/100
# 1021/1021 - 5s - loss: 5.7934e-04 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1021/1021 - 5s - loss: 5.7406e-04 - 5s/epoch - 5ms/step
# Epoch 9/100
# 1021/1021 - 5s - loss: 5.0733e-04 - 5s/epoch - 5ms/step
# Epoch 10/100
# 1021/1021 - 5s - loss: 4.6046e-04 - 5s/epoch - 4ms/step
# Epoch 11/100
# 1021/1021 - 5s - loss: 3.2321e-04 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1021/1021 - 4s - loss: 4.0249e-04 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1021/1021 - 5s - loss: 3.5463e-04 - 5s/epoch - 5ms/step
# Epoch 14/100
# 1021/1021 - 5s - loss: 2.8891e-04 - 5s/epoch - 5ms/step
# Epoch 15/100
# 1021/1021 - 5s - loss: 2.5007e-04 - 5s/epoch - 5ms/step
# Epoch 16/100
# 1021/1021 - 5s - loss: 2.2887e-04 - 5s/epoch - 5ms/step
# Epoch 17/100
# 1021/1021 - 5s - loss: 2.8869e-04 - 5s/epoch - 5ms/step
# Epoch 18/100
# 1021/1021 - 5s - loss: 2.1123e-04 - 5s/epoch - 5ms/step
# Epoch 19/100
# 1021/1021 - 5s - loss: 2.4541e-04 - 5s/epoch - 5ms/step
# Epoch 20/100
# 1021/1021 - 5s - loss: 2.2142e-04 - 5s/epoch - 5ms/step
# Epoch 21/100
# 1021/1021 - 5s - loss: 2.2024e-04 - 5s/epoch - 5ms/step
# Epoch 22/100
# 1021/1021 - 5s - loss: 2.0975e-04 - 5s/epoch - 5ms/step
# Epoch 23/100
# 1021/1021 - 5s - loss: 2.0207e-04 - 5s/epoch - 5ms/step
# Epoch 24/100
# 1021/1021 - 5s - loss: 2.3980e-04 - 5s/epoch - 5ms/step
# Epoch 25/100
# 1021/1021 - 5s - loss: 2.0707e-04 - 5s/epoch - 5ms/step
# Epoch 26/100
# 1021/1021 - 5s - loss: 2.2747e-04 - 5s/epoch - 5ms/step
# Epoch 27/100
# 1021/1021 - 5s - loss: 2.4804e-04 - 5s/epoch - 5ms/step
# Epoch 28/100
# 1021/1021 - 5s - loss: 2.1410e-04 - 5s/epoch - 5ms/step
# Epoch 29/100
# 1021/1021 - 5s - loss: 2.5904e-04 - 5s/epoch - 5ms/step
# Epoch 30/100
# 1021/1021 - 5s - loss: 1.9590e-04 - 5s/epoch - 5ms/step
# Epoch 31/100
# 1021/1021 - 5s - loss: 2.5064e-04 - 5s/epoch - 5ms/step
# Epoch 32/100
# 1021/1021 - 5s - loss: 2.2493e-04 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1021/1021 - 5s - loss: 2.3877e-04 - 5s/epoch - 5ms/step
# Epoch 34/100
# 1021/1021 - 5s - loss: 2.0676e-04 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1021/1021 - 5s - loss: 2.3547e-04 - 5s/epoch - 5ms/step
# Epoch 36/100
# 1021/1021 - 5s - loss: 2.2369e-04 - 5s/epoch - 5ms/step
# Epoch 37/100
# 1021/1021 - 5s - loss: 2.1373e-04 - 5s/epoch - 5ms/step
# Epoch 38/100
# 1021/1021 - 5s - loss: 2.1247e-04 - 5s/epoch - 5ms/step
# Epoch 39/100
# 1021/1021 - 5s - loss: 2.0195e-04 - 5s/epoch - 5ms/step
# Epoch 40/100
# 1021/1021 - 5s - loss: 1.9654e-04 - 5s/epoch - 5ms/step
# Epoch 41/100
# 1021/1021 - 5s - loss: 2.2054e-04 - 5s/epoch - 4ms/step
# Epoch 42/100
# 1021/1021 - 5s - loss: 2.1696e-04 - 5s/epoch - 5ms/step
# Epoch 43/100
# 1021/1021 - 5s - loss: 2.0630e-04 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1021/1021 - 5s - loss: 2.2677e-04 - 5s/epoch - 5ms/step
# Epoch 45/100
# 1021/1021 - 5s - loss: 1.9789e-04 - 5s/epoch - 4ms/step
# Epoch 46/100
# 1021/1021 - 5s - loss: 2.1817e-04 - 5s/epoch - 5ms/step
# Epoch 47/100
# 1021/1021 - 5s - loss: 2.0994e-04 - 5s/epoch - 5ms/step
# Epoch 48/100
# 1021/1021 - 5s - loss: 2.1082e-04 - 5s/epoch - 5ms/step
# Epoch 49/100
# 1021/1021 - 5s - loss: 1.9728e-04 - 5s/epoch - 5ms/step
# Epoch 50/100
# 1021/1021 - 5s - loss: 1.9867e-04 - 5s/epoch - 5ms/step
# Epoch 51/100
# 1021/1021 - 5s - loss: 1.9876e-04 - 5s/epoch - 5ms/step
# Epoch 52/100
# 1021/1021 - 5s - loss: 2.1157e-04 - 5s/epoch - 5ms/step
# Epoch 53/100
# 1021/1021 - 5s - loss: 2.1318e-04 - 5s/epoch - 5ms/step
# Epoch 54/100
# 1021/1021 - 5s - loss: 1.9296e-04 - 5s/epoch - 4ms/step
# Epoch 55/100
# 1021/1021 - 5s - loss: 2.1984e-04 - 5s/epoch - 5ms/step
# Epoch 56/100
# 1021/1021 - 4s - loss: 1.9617e-04 - 4s/epoch - 4ms/step
# Epoch 57/100
# 1021/1021 - 5s - loss: 2.0108e-04 - 5s/epoch - 5ms/step
# Epoch 58/100
# 1021/1021 - 5s - loss: 2.0736e-04 - 5s/epoch - 4ms/step
# Epoch 59/100
# 1021/1021 - 5s - loss: 2.0064e-04 - 5s/epoch - 5ms/step
# Epoch 60/100
# 1021/1021 - 5s - loss: 1.9767e-04 - 5s/epoch - 5ms/step
# Epoch 61/100
# 1021/1021 - 5s - loss: 2.2884e-04 - 5s/epoch - 5ms/step
# Epoch 62/100
# 1021/1021 - 5s - loss: 2.2836e-04 - 5s/epoch - 4ms/step
# Epoch 63/100
# 1021/1021 - 5s - loss: 2.0323e-04 - 5s/epoch - 5ms/step
# Epoch 64/100
# 1021/1021 - 5s - loss: 2.2687e-04 - 5s/epoch - 5ms/step
# Epoch 65/100
# 1021/1021 - 5s - loss: 2.0040e-04 - 5s/epoch - 5ms/step
# Epoch 66/100
# 1021/1021 - 5s - loss: 2.0449e-04 - 5s/epoch - 5ms/step
# Epoch 67/100
# 1021/1021 - 5s - loss: 2.2136e-04 - 5s/epoch - 5ms/step
# Epoch 68/100
# 1021/1021 - 5s - loss: 2.3803e-04 - 5s/epoch - 5ms/step
# Epoch 69/100
# 1021/1021 - 5s - loss: 1.9722e-04 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1021/1021 - 5s - loss: 1.8915e-04 - 5s/epoch - 5ms/step
# Epoch 71/100
# 1021/1021 - 5s - loss: 2.0353e-04 - 5s/epoch - 5ms/step
# Epoch 72/100
# 1021/1021 - 5s - loss: 2.0559e-04 - 5s/epoch - 5ms/step
# Epoch 73/100
# 1021/1021 - 5s - loss: 2.1135e-04 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1021/1021 - 5s - loss: 2.1198e-04 - 5s/epoch - 5ms/step
# Epoch 75/100
# 1021/1021 - 5s - loss: 2.0720e-04 - 5s/epoch - 5ms/step
# Epoch 76/100
# 1021/1021 - 5s - loss: 2.1109e-04 - 5s/epoch - 5ms/step
# Epoch 77/100
# 1021/1021 - 5s - loss: 2.0164e-04 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1021/1021 - 5s - loss: 2.0064e-04 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1021/1021 - 5s - loss: 2.3967e-04 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1021/1021 - 5s - loss: 2.2777e-04 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1021/1021 - 5s - loss: 2.0047e-04 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1021/1021 - 5s - loss: 2.3351e-04 - 5s/epoch - 5ms/step
# Epoch 83/100
# 1021/1021 - 5s - loss: 2.2349e-04 - 5s/epoch - 5ms/step
# Epoch 84/100
# 1021/1021 - 5s - loss: 2.0520e-04 - 5s/epoch - 4ms/step
# Epoch 85/100
# 1021/1021 - 5s - loss: 2.0413e-04 - 5s/epoch - 5ms/step
# Epoch 86/100
# 1021/1021 - 5s - loss: 1.7417e-04 - 5s/epoch - 5ms/step
# Epoch 87/100
# 1021/1021 - 5s - loss: 2.2632e-04 - 5s/epoch - 5ms/step
# Epoch 88/100
# 1021/1021 - 5s - loss: 1.9988e-04 - 5s/epoch - 5ms/step
# Epoch 89/100
# 1021/1021 - 5s - loss: 2.1139e-04 - 5s/epoch - 5ms/step
# Epoch 90/100
# 1021/1021 - 5s - loss: 2.2538e-04 - 5s/epoch - 5ms/step
# Epoch 91/100
# 1021/1021 - 5s - loss: 2.1041e-04 - 5s/epoch - 5ms/step
# Epoch 92/100
# 1021/1021 - 5s - loss: 2.2963e-04 - 5s/epoch - 5ms/step
# Epoch 93/100
# 1021/1021 - 5s - loss: 1.9857e-04 - 5s/epoch - 5ms/step
# Epoch 94/100
# 1021/1021 - 5s - loss: 1.9605e-04 - 5s/epoch - 5ms/step
# Epoch 95/100
# 1021/1021 - 5s - loss: 2.0549e-04 - 5s/epoch - 5ms/step
# Epoch 96/100
# 1021/1021 - 5s - loss: 2.3556e-04 - 5s/epoch - 5ms/step
# Epoch 97/100
# 1021/1021 - 5s - loss: 2.1040e-04 - 5s/epoch - 5ms/step
# Epoch 98/100
# 1021/1021 - 5s - loss: 1.9979e-04 - 5s/epoch - 5ms/step
# Epoch 99/100
# 1021/1021 - 5s - loss: 2.0184e-04 - 5s/epoch - 5ms/step
# Epoch 100/100
# 1021/1021 - 5s - loss: 2.0816e-04 - 5s/epoch - 5ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 32/32 [==============================] - 1s 4ms/step
# 16/16 [==============================] - 0s 4ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
"""train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse) """

from sklearn.metrics import r2_score
import math
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(train, train_predict))
test_rmse = np.sqrt(mean_squared_error(test, test_predict))
print('R2 Score_train:', r2_score(train, train_predict))
print('R2 Score_test:', r2_score(test, test_predict))

print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# R2 Score_train: 0.9997357864391194
# R2 Score_test: 0.9997172529343665
# Train RMSE: 0.23
# Test RMSE: 0.23

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lastm_10.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0     [37.099998474121094]   [37.21154022216797]
# 1      [67.44999694824219]   [67.78861999511719]
# 2     [30.559999465942383]  [30.536746978759766]
# 3      [45.86000442504883]   [46.13665008544922]
# 4      [36.93000030517578]   [37.03805160522461]
# ...                    ...                   ...
# 1016  [20.739999771118164]   [20.54182243347168]
# 1017  [19.270000457763672]  [19.051830291748047]
# 1018  [13.859999656677246]   [13.58905029296875]
# 1019  [38.301639556884766]  [38.437679290771484]
# 1020  [38.301639556884766]  [38.437679290771484]
#
# [1021 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lastm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0    [38.301639556884766]  [38.437679290771484]
# 1    [38.301639556884766]  [38.437679290771484]
# 2    [38.301639556884766]  [38.437679290771484]
# 3    [38.301639556884766]  [38.437679290771484]
# 4    [38.301639556884766]  [38.437679290771484]
# ..                    ...                   ...
# 499   [38.36000061035156]   [38.49721908569336]
# 500   [46.47999954223633]   [46.76660919189453]
# 501   [62.20000076293945]   [62.59189224243164]
# 502    [38.9900016784668]   [39.13990783691406]
# 503  [47.720001220703125]   [48.02558135986328]
#
# [504 rows x 2 columns]
