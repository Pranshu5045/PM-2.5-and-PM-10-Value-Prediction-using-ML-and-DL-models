# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Thane_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 952/952 - 14s - loss: 0.0038 - 14s/epoch - 15ms/step
# Epoch 2/100
# 952/952 - 6s - loss: 0.0012 - 6s/epoch - 6ms/step
# Epoch 3/100
# 952/952 - 6s - loss: 5.3050e-04 - 6s/epoch - 6ms/step
# Epoch 4/100
# 952/952 - 6s - loss: 2.7422e-04 - 6s/epoch - 6ms/step
# Epoch 5/100
# 952/952 - 6s - loss: 1.6314e-04 - 6s/epoch - 6ms/step
# Epoch 6/100
# 952/952 - 6s - loss: 1.1460e-04 - 6s/epoch - 6ms/step
# Epoch 7/100
# 952/952 - 6s - loss: 9.5303e-05 - 6s/epoch - 6ms/step
# Epoch 8/100
# 952/952 - 6s - loss: 8.9440e-05 - 6s/epoch - 6ms/step
# Epoch 9/100
# 952/952 - 6s - loss: 7.5663e-05 - 6s/epoch - 6ms/step
# Epoch 10/100
# 952/952 - 6s - loss: 8.5466e-05 - 6s/epoch - 6ms/step
# Epoch 11/100
# 952/952 - 6s - loss: 6.4601e-05 - 6s/epoch - 6ms/step
# Epoch 12/100
# 952/952 - 6s - loss: 5.0335e-05 - 6s/epoch - 6ms/step
# Epoch 13/100
# 952/952 - 6s - loss: 4.1911e-05 - 6s/epoch - 6ms/step
# Epoch 14/100
# 952/952 - 6s - loss: 5.9297e-05 - 6s/epoch - 6ms/step
# Epoch 15/100
# 952/952 - 6s - loss: 1.2241e-04 - 6s/epoch - 6ms/step
# Epoch 16/100
# 952/952 - 6s - loss: 4.6056e-05 - 6s/epoch - 6ms/step
# Epoch 17/100
# 952/952 - 6s - loss: 7.3834e-05 - 6s/epoch - 6ms/step
# Epoch 18/100
# 952/952 - 6s - loss: 3.7324e-05 - 6s/epoch - 6ms/step
# Epoch 19/100
# 952/952 - 6s - loss: 5.5434e-05 - 6s/epoch - 6ms/step
# Epoch 20/100
# 952/952 - 6s - loss: 1.1621e-04 - 6s/epoch - 6ms/step
# Epoch 21/100
# 952/952 - 6s - loss: 4.3040e-05 - 6s/epoch - 6ms/step
# Epoch 22/100
# 952/952 - 6s - loss: 1.2191e-04 - 6s/epoch - 6ms/step
# Epoch 23/100
# 952/952 - 6s - loss: 3.2379e-05 - 6s/epoch - 6ms/step
# Epoch 24/100
# 952/952 - 6s - loss: 5.1720e-05 - 6s/epoch - 6ms/step
# Epoch 25/100
# 952/952 - 6s - loss: 3.7035e-05 - 6s/epoch - 6ms/step
# Epoch 26/100
# 952/952 - 6s - loss: 4.7710e-05 - 6s/epoch - 6ms/step
# Epoch 27/100
# 952/952 - 6s - loss: 8.0325e-05 - 6s/epoch - 6ms/step
# Epoch 28/100
# 952/952 - 6s - loss: 4.8252e-05 - 6s/epoch - 6ms/step
# Epoch 29/100
# 952/952 - 6s - loss: 5.5118e-05 - 6s/epoch - 6ms/step
# Epoch 30/100
# 952/952 - 6s - loss: 6.5747e-05 - 6s/epoch - 6ms/step
# Epoch 31/100
# 952/952 - 6s - loss: 3.6579e-05 - 6s/epoch - 6ms/step
# Epoch 32/100
# 952/952 - 6s - loss: 6.5010e-05 - 6s/epoch - 6ms/step
# Epoch 33/100
# 952/952 - 6s - loss: 5.5484e-05 - 6s/epoch - 6ms/step
# Epoch 34/100
# 952/952 - 6s - loss: 1.8812e-05 - 6s/epoch - 6ms/step
# Epoch 35/100
# 952/952 - 6s - loss: 6.7542e-05 - 6s/epoch - 6ms/step
# Epoch 36/100
# 952/952 - 6s - loss: 6.4051e-05 - 6s/epoch - 6ms/step
# Epoch 37/100
# 952/952 - 6s - loss: 7.5274e-05 - 6s/epoch - 6ms/step
# Epoch 38/100
# 952/952 - 6s - loss: 4.3371e-05 - 6s/epoch - 6ms/step
# Epoch 39/100
# 952/952 - 6s - loss: 6.6754e-05 - 6s/epoch - 7ms/step
# Epoch 40/100
# 952/952 - 6s - loss: 6.3964e-05 - 6s/epoch - 7ms/step
# Epoch 41/100
# 952/952 - 6s - loss: 4.5583e-05 - 6s/epoch - 7ms/step
# Epoch 42/100
# 952/952 - 6s - loss: 8.5254e-05 - 6s/epoch - 6ms/step
# Epoch 43/100
# 952/952 - 6s - loss: 4.2813e-05 - 6s/epoch - 6ms/step
# Epoch 44/100
# 952/952 - 6s - loss: 3.2623e-05 - 6s/epoch - 6ms/step
# Epoch 45/100
# 952/952 - 6s - loss: 5.2091e-05 - 6s/epoch - 6ms/step
# Epoch 46/100
# 952/952 - 6s - loss: 6.9842e-05 - 6s/epoch - 6ms/step
# Epoch 47/100
# 952/952 - 6s - loss: 7.2182e-05 - 6s/epoch - 6ms/step
# Epoch 48/100
# 952/952 - 6s - loss: 2.9390e-05 - 6s/epoch - 6ms/step
# Epoch 49/100
# 952/952 - 6s - loss: 3.5535e-05 - 6s/epoch - 6ms/step
# Epoch 50/100
# 952/952 - 6s - loss: 5.7034e-05 - 6s/epoch - 6ms/step
# Epoch 51/100
# 952/952 - 6s - loss: 7.8922e-05 - 6s/epoch - 6ms/step
# Epoch 52/100
# 952/952 - 6s - loss: 4.9156e-05 - 6s/epoch - 6ms/step
# Epoch 53/100
# 952/952 - 6s - loss: 4.8113e-05 - 6s/epoch - 6ms/step
# Epoch 54/100
# 952/952 - 6s - loss: 1.9561e-05 - 6s/epoch - 6ms/step
# Epoch 55/100
# 952/952 - 6s - loss: 4.8766e-05 - 6s/epoch - 6ms/step
# Epoch 56/100
# 952/952 - 6s - loss: 5.4023e-05 - 6s/epoch - 6ms/step
# Epoch 57/100
# 952/952 - 6s - loss: 2.1966e-05 - 6s/epoch - 6ms/step
# Epoch 58/100
# 952/952 - 6s - loss: 3.2588e-05 - 6s/epoch - 6ms/step
# Epoch 59/100
# 952/952 - 6s - loss: 4.6646e-05 - 6s/epoch - 6ms/step
# Epoch 60/100
# 952/952 - 7s - loss: 7.6554e-05 - 7s/epoch - 7ms/step
# Epoch 61/100
# 952/952 - 6s - loss: 1.2530e-04 - 6s/epoch - 6ms/step
# Epoch 62/100
# 952/952 - 6s - loss: 5.0214e-05 - 6s/epoch - 6ms/step
# Epoch 63/100
# 952/952 - 6s - loss: 7.9158e-05 - 6s/epoch - 6ms/step
# Epoch 64/100
# 952/952 - 11s - loss: 3.7074e-05 - 11s/epoch - 12ms/step
# Epoch 65/100
# 952/952 - 6s - loss: 1.3982e-05 - 6s/epoch - 6ms/step
# Epoch 66/100
# 952/952 - 6s - loss: 6.3286e-05 - 6s/epoch - 7ms/step
# Epoch 67/100
# 952/952 - 6s - loss: 2.5643e-05 - 6s/epoch - 6ms/step
# Epoch 68/100
# 952/952 - 6s - loss: 7.4947e-05 - 6s/epoch - 6ms/step
# Epoch 69/100
# 952/952 - 6s - loss: 4.0526e-05 - 6s/epoch - 6ms/step
# Epoch 70/100
# 952/952 - 6s - loss: 5.6141e-05 - 6s/epoch - 6ms/step
# Epoch 71/100
# 952/952 - 6s - loss: 4.7248e-05 - 6s/epoch - 6ms/step
# Epoch 72/100
# 952/952 - 6s - loss: 2.9423e-05 - 6s/epoch - 6ms/step
# Epoch 73/100
# 952/952 - 6s - loss: 5.2399e-05 - 6s/epoch - 6ms/step
# Epoch 74/100
# 952/952 - 6s - loss: 5.2843e-05 - 6s/epoch - 6ms/step
# Epoch 75/100
# 952/952 - 6s - loss: 7.3909e-05 - 6s/epoch - 6ms/step
# Epoch 76/100
# 952/952 - 6s - loss: 4.2565e-05 - 6s/epoch - 6ms/step
# Epoch 77/100
# 952/952 - 6s - loss: 9.7441e-05 - 6s/epoch - 6ms/step
# Epoch 78/100
# 952/952 - 6s - loss: 7.4723e-05 - 6s/epoch - 6ms/step
# Epoch 79/100
# 952/952 - 6s - loss: 3.1637e-05 - 6s/epoch - 6ms/step
# Epoch 80/100
# 952/952 - 6s - loss: 5.9027e-05 - 6s/epoch - 6ms/step
# Epoch 81/100
# 952/952 - 6s - loss: 1.3735e-05 - 6s/epoch - 6ms/step
# Epoch 82/100
# 952/952 - 6s - loss: 7.3026e-05 - 6s/epoch - 6ms/step
# Epoch 83/100
# 952/952 - 6s - loss: 3.5045e-05 - 6s/epoch - 6ms/step
# Epoch 84/100
# 952/952 - 6s - loss: 1.7568e-05 - 6s/epoch - 6ms/step
# Epoch 85/100
# 952/952 - 6s - loss: 4.2130e-05 - 6s/epoch - 6ms/step
# Epoch 86/100
# 952/952 - 6s - loss: 3.2861e-05 - 6s/epoch - 6ms/step
# Epoch 87/100
# 952/952 - 6s - loss: 6.9961e-05 - 6s/epoch - 6ms/step
# Epoch 88/100
# 952/952 - 6s - loss: 6.0389e-05 - 6s/epoch - 6ms/step
# Epoch 89/100
# 952/952 - 5s - loss: 3.8456e-05 - 5s/epoch - 6ms/step
# Epoch 90/100
# 952/952 - 5s - loss: 5.9960e-05 - 5s/epoch - 5ms/step
# Epoch 91/100
# 952/952 - 5s - loss: 2.6306e-05 - 5s/epoch - 5ms/step
# Epoch 92/100
# 952/952 - 5s - loss: 1.2256e-05 - 5s/epoch - 5ms/step
# Epoch 93/100
# 952/952 - 5s - loss: 5.6254e-05 - 5s/epoch - 5ms/step
# Epoch 94/100
# 952/952 - 5s - loss: 6.6662e-05 - 5s/epoch - 5ms/step
# Epoch 95/100
# 952/952 - 5s - loss: 4.6555e-05 - 5s/epoch - 5ms/step
# Epoch 96/100
# 952/952 - 5s - loss: 9.7113e-05 - 5s/epoch - 5ms/step
# Epoch 97/100
# 952/952 - 5s - loss: 6.3032e-05 - 5s/epoch - 5ms/step
# Epoch 98/100
# 952/952 - 5s - loss: 2.5880e-05 - 5s/epoch - 5ms/step
# Epoch 99/100
# 952/952 - 5s - loss: 4.3437e-05 - 5s/epoch - 5ms/step
# Epoch 100/100
# 952/952 - 5s - loss: 5.9073e-05 - 5s/epoch - 5ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 30/30 [==============================] - 2s 5ms/step
# 15/15 [==============================] - 0s 5ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
"""train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)"""
from sklearn.metrics import r2_score
import math
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(train, train_predict))
test_rmse = np.sqrt(mean_squared_error(test, test_predict))
print('R2 Score_train:', r2_score(train, train_predict))
print('R2 Score_test:', r2_score(test, test_predict))

print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# R2 Score_train: 0.9996425671573155
# R2 Score_test: 0.9996567554823731
# Train RMSE: 0.02
# Test RMSE: 0.03

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_2.5.xlsx')
df
# Out:
#                   Actual  Predicted from lstm
# 0    [68.61000061035156]   [68.6101303100586]
# 1    [64.37999725341797]  [64.39669799804688]
# 2    [81.83000183105469]  [82.06047058105469]
# 3    [76.73999786376953]  [76.91163635253906]
# 4    [68.83999633789062]  [68.84258270263672]
# ..                   ...                  ...
# 947  [68.89774322509766]  [68.90098571777344]
# 948  [68.89774322509766]  [68.90098571777344]
# 949  [68.89774322509766]  [68.90098571777344]
# 950  [68.89774322509766]  [68.90098571777344]
# 951  [68.89774322509766]  [68.90098571777344]
#
# [952 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_2.5_test.xlsx')
df
# Out:
#                   Actual  Predicted from lstm
# 0    [68.89774322509766]  [68.90098571777344]
# 1    [68.89774322509766]  [68.90098571777344]
# 2    [68.89774322509766]  [68.90098571777344]
# 3    [68.89774322509766]  [68.90098571777344]
# 4    [68.89774322509766]  [68.90098571777344]
# ..                   ...                  ...
# 465  [68.89774322509766]  [68.90098571777344]
# 466  [68.89774322509766]  [68.90098571777344]
# 467  [68.89774322509766]  [68.90098571777344]
# 468  [68.89774322509766]  [68.90098571777344]
# 469  [68.89774322509766]  [68.90098571777344]
#
# [470 rows x 2 columns]
