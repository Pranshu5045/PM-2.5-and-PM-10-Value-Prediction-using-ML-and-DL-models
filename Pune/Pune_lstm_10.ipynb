# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Pune_lstm_10.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 998/998 - 13s - loss: 0.0159 - 13s/epoch - 13ms/step
# Epoch 2/100
# 998/998 - 6s - loss: 0.0011 - 6s/epoch - 6ms/step
# Epoch 3/100
# 998/998 - 6s - loss: 0.0010 - 6s/epoch - 6ms/step
# Epoch 4/100
# 998/998 - 6s - loss: 9.2358e-04 - 6s/epoch - 6ms/step
# Epoch 5/100
# 998/998 - 5s - loss: 9.2205e-04 - 5s/epoch - 5ms/step
# Epoch 6/100
# 998/998 - 5s - loss: 7.4580e-04 - 5s/epoch - 5ms/step
# Epoch 7/100
# 998/998 - 5s - loss: 6.3542e-04 - 5s/epoch - 5ms/step
# Epoch 8/100
# 998/998 - 5s - loss: 5.3223e-04 - 5s/epoch - 5ms/step
# Epoch 9/100
# 998/998 - 5s - loss: 4.5536e-04 - 5s/epoch - 5ms/step
# Epoch 10/100
# 998/998 - 5s - loss: 4.6362e-04 - 5s/epoch - 5ms/step
# Epoch 11/100
# 998/998 - 5s - loss: 3.6797e-04 - 5s/epoch - 5ms/step
# Epoch 12/100
# 998/998 - 6s - loss: 4.9123e-04 - 6s/epoch - 6ms/step
# Epoch 13/100
# 998/998 - 6s - loss: 4.4722e-04 - 6s/epoch - 6ms/step
# Epoch 14/100
# 998/998 - 6s - loss: 4.1327e-04 - 6s/epoch - 6ms/step
# Epoch 15/100
# 998/998 - 5s - loss: 4.1213e-04 - 5s/epoch - 5ms/step
# Epoch 16/100
# 998/998 - 5s - loss: 3.5936e-04 - 5s/epoch - 5ms/step
# Epoch 17/100
# 998/998 - 6s - loss: 3.7222e-04 - 6s/epoch - 6ms/step
# Epoch 18/100
# 998/998 - 6s - loss: 4.3592e-04 - 6s/epoch - 6ms/step
# Epoch 19/100
# 998/998 - 6s - loss: 4.4332e-04 - 6s/epoch - 6ms/step
# Epoch 20/100
# 998/998 - 6s - loss: 4.6107e-04 - 6s/epoch - 6ms/step
# Epoch 21/100
# 998/998 - 6s - loss: 3.3346e-04 - 6s/epoch - 6ms/step
# Epoch 22/100
# 998/998 - 6s - loss: 3.8575e-04 - 6s/epoch - 6ms/step
# Epoch 23/100
# 998/998 - 6s - loss: 4.1476e-04 - 6s/epoch - 6ms/step
# Epoch 24/100
# 998/998 - 6s - loss: 3.1538e-04 - 6s/epoch - 6ms/step
# Epoch 25/100
# 998/998 - 6s - loss: 3.5733e-04 - 6s/epoch - 6ms/step
# Epoch 26/100
# 998/998 - 6s - loss: 3.2227e-04 - 6s/epoch - 6ms/step
# Epoch 27/100
# 998/998 - 6s - loss: 3.5855e-04 - 6s/epoch - 6ms/step
# Epoch 28/100
# 998/998 - 6s - loss: 3.8195e-04 - 6s/epoch - 6ms/step
# Epoch 29/100
# 998/998 - 6s - loss: 3.4658e-04 - 6s/epoch - 6ms/step
# Epoch 30/100
# 998/998 - 6s - loss: 3.3153e-04 - 6s/epoch - 6ms/step
# Epoch 31/100
# 998/998 - 6s - loss: 3.3657e-04 - 6s/epoch - 6ms/step
# Epoch 32/100
# 998/998 - 6s - loss: 3.8268e-04 - 6s/epoch - 6ms/step
# Epoch 33/100
# 998/998 - 6s - loss: 3.8432e-04 - 6s/epoch - 6ms/step
# Epoch 34/100
# 998/998 - 6s - loss: 3.7835e-04 - 6s/epoch - 6ms/step
# Epoch 35/100
# 998/998 - 6s - loss: 4.0901e-04 - 6s/epoch - 6ms/step
# Epoch 36/100
# 998/998 - 6s - loss: 3.5321e-04 - 6s/epoch - 6ms/step
# Epoch 37/100
# 998/998 - 6s - loss: 3.5927e-04 - 6s/epoch - 6ms/step
# Epoch 38/100
# 998/998 - 6s - loss: 4.0679e-04 - 6s/epoch - 6ms/step
# Epoch 39/100
# 998/998 - 6s - loss: 3.7750e-04 - 6s/epoch - 6ms/step
# Epoch 40/100
# 998/998 - 6s - loss: 3.6314e-04 - 6s/epoch - 6ms/step
# Epoch 41/100
# 998/998 - 6s - loss: 3.6352e-04 - 6s/epoch - 6ms/step
# Epoch 42/100
# 998/998 - 6s - loss: 4.0024e-04 - 6s/epoch - 6ms/step
# Epoch 43/100
# 998/998 - 6s - loss: 3.5377e-04 - 6s/epoch - 6ms/step
# Epoch 44/100
# 998/998 - 6s - loss: 3.9560e-04 - 6s/epoch - 6ms/step
# Epoch 45/100
# 998/998 - 6s - loss: 3.6796e-04 - 6s/epoch - 6ms/step
# Epoch 46/100
# 998/998 - 6s - loss: 3.6696e-04 - 6s/epoch - 6ms/step
# Epoch 47/100
# 998/998 - 6s - loss: 3.7065e-04 - 6s/epoch - 6ms/step
# Epoch 48/100
# 998/998 - 6s - loss: 3.9575e-04 - 6s/epoch - 6ms/step
# Epoch 49/100
# 998/998 - 6s - loss: 3.6069e-04 - 6s/epoch - 6ms/step
# Epoch 50/100
# 998/998 - 6s - loss: 3.7063e-04 - 6s/epoch - 6ms/step
# Epoch 51/100
# 998/998 - 6s - loss: 3.7116e-04 - 6s/epoch - 6ms/step
# Epoch 52/100
# 998/998 - 6s - loss: 3.4150e-04 - 6s/epoch - 6ms/step
# Epoch 53/100
# 998/998 - 6s - loss: 3.6083e-04 - 6s/epoch - 6ms/step
# Epoch 54/100
# 998/998 - 7s - loss: 3.1332e-04 - 7s/epoch - 7ms/step
# Epoch 55/100
# 998/998 - 6s - loss: 3.9122e-04 - 6s/epoch - 6ms/step
# Epoch 56/100
# 998/998 - 6s - loss: 3.1202e-04 - 6s/epoch - 6ms/step
# Epoch 57/100
# 998/998 - 6s - loss: 3.7171e-04 - 6s/epoch - 6ms/step
# Epoch 58/100
# 998/998 - 6s - loss: 3.4700e-04 - 6s/epoch - 6ms/step
# Epoch 59/100
# 998/998 - 6s - loss: 3.6196e-04 - 6s/epoch - 6ms/step
# Epoch 60/100
# 998/998 - 6s - loss: 3.9193e-04 - 6s/epoch - 6ms/step
# Epoch 61/100
# 998/998 - 6s - loss: 3.5424e-04 - 6s/epoch - 6ms/step
# Epoch 62/100
# 998/998 - 6s - loss: 3.7538e-04 - 6s/epoch - 6ms/step
# Epoch 63/100
# 998/998 - 6s - loss: 3.4525e-04 - 6s/epoch - 6ms/step
# Epoch 64/100
# 998/998 - 6s - loss: 3.7011e-04 - 6s/epoch - 6ms/step
# Epoch 65/100
# 998/998 - 6s - loss: 2.9360e-04 - 6s/epoch - 6ms/step
# Epoch 66/100
# 998/998 - 6s - loss: 4.2670e-04 - 6s/epoch - 6ms/step
# Epoch 67/100
# 998/998 - 6s - loss: 3.4304e-04 - 6s/epoch - 6ms/step
# Epoch 68/100
# 998/998 - 6s - loss: 3.6657e-04 - 6s/epoch - 6ms/step
# Epoch 69/100
# 998/998 - 6s - loss: 3.0762e-04 - 6s/epoch - 6ms/step
# Epoch 70/100
# 998/998 - 6s - loss: 3.9509e-04 - 6s/epoch - 6ms/step
# Epoch 71/100
# 998/998 - 6s - loss: 3.3433e-04 - 6s/epoch - 6ms/step
# Epoch 72/100
# 998/998 - 6s - loss: 3.4508e-04 - 6s/epoch - 6ms/step
# Epoch 73/100
# 998/998 - 7s - loss: 3.9375e-04 - 7s/epoch - 7ms/step
# Epoch 74/100
# 998/998 - 6s - loss: 3.4678e-04 - 6s/epoch - 6ms/step
# Epoch 75/100
# 998/998 - 6s - loss: 4.1570e-04 - 6s/epoch - 6ms/step
# Epoch 76/100
# 998/998 - 6s - loss: 3.7901e-04 - 6s/epoch - 6ms/step
# Epoch 77/100
# 998/998 - 12s - loss: 3.5439e-04 - 12s/epoch - 12ms/step
# Epoch 78/100
# 998/998 - 6s - loss: 3.3524e-04 - 6s/epoch - 6ms/step
# Epoch 79/100
# 998/998 - 7s - loss: 3.3173e-04 - 7s/epoch - 7ms/step
# Epoch 80/100
# 998/998 - 6s - loss: 3.5443e-04 - 6s/epoch - 6ms/step
# Epoch 81/100
# 998/998 - 6s - loss: 3.9936e-04 - 6s/epoch - 6ms/step
# Epoch 82/100
# 998/998 - 6s - loss: 3.3837e-04 - 6s/epoch - 6ms/step
# Epoch 83/100
# 998/998 - 6s - loss: 3.6145e-04 - 6s/epoch - 6ms/step
# Epoch 84/100
# 998/998 - 6s - loss: 3.5843e-04 - 6s/epoch - 6ms/step
# Epoch 85/100
# 998/998 - 6s - loss: 3.3649e-04 - 6s/epoch - 6ms/step
# Epoch 86/100
# 998/998 - 6s - loss: 3.2152e-04 - 6s/epoch - 6ms/step
# Epoch 87/100
# 998/998 - 6s - loss: 3.3688e-04 - 6s/epoch - 6ms/step
# Epoch 88/100
# 998/998 - 6s - loss: 4.1734e-04 - 6s/epoch - 6ms/step
# Epoch 89/100
# 998/998 - 6s - loss: 3.9429e-04 - 6s/epoch - 6ms/step
# Epoch 90/100
# 998/998 - 6s - loss: 3.2057e-04 - 6s/epoch - 6ms/step
# Epoch 91/100
# 998/998 - 6s - loss: 3.4342e-04 - 6s/epoch - 6ms/step
# Epoch 92/100
# 998/998 - 6s - loss: 3.4131e-04 - 6s/epoch - 6ms/step
# Epoch 93/100
# 998/998 - 6s - loss: 3.3720e-04 - 6s/epoch - 6ms/step
# Epoch 94/100
# 998/998 - 6s - loss: 3.0657e-04 - 6s/epoch - 6ms/step
# Epoch 95/100
# 998/998 - 6s - loss: 3.3860e-04 - 6s/epoch - 6ms/step
# Epoch 96/100
# 998/998 - 6s - loss: 3.7669e-04 - 6s/epoch - 6ms/step
# Epoch 97/100
# 998/998 - 6s - loss: 2.9588e-04 - 6s/epoch - 6ms/step
# Epoch 98/100
# 998/998 - 6s - loss: 3.1327e-04 - 6s/epoch - 6ms/step
# Epoch 99/100
# 998/998 - 6s - loss: 3.3003e-04 - 6s/epoch - 6ms/step
# Epoch 100/100
# 998/998 - 6s - loss: 3.5582e-04 - 6s/epoch - 6ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 32/32 [==============================] - 3s 5ms/step
# 16/16 [==============================] - 0s 5ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
"""train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)"""
from sklearn.metrics import r2_score
import math
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(train, train_predict))
test_rmse = np.sqrt(mean_squared_error(test, test_predict))
print('R2 Score_train:', r2_score(train, train_predict))
print('R2 Score_test:', r2_score(test, test_predict))

print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# R2 Score_train: 0.9997877335913602
# R2 Score_test: 0.9997413042681056
# Train RMSE: 0.55
# Test RMSE: 0.33

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_10.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [153.0399932861328]   [151.2400665283203]
# 1     [151.9499969482422]  [150.20127868652344]
# 2    [159.32000732421875]  [157.20025634765625]
# 3     [148.5500030517578]          [146.953125]
# 4    [142.16000366210938]  [140.81761169433594]
# ..                    ...                   ...
# 993   [65.51000213623047]   [65.28572082519531]
# 994                [69.0]   [68.75485229492188]
# 995   [65.05000305175781]   [64.82860565185547]
# 996  [51.849998474121094]  [51.731468200683594]
# 997   [62.33000183105469]   [62.12636947631836]
#
# [998 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_10_test.xlsx')
df
# Out:
#                   Actual   Predicted from lstm
# 0     [65.6500015258789]   [65.42485046386719]
# 1    [49.78000259399414]   [49.68238067626953]
# 2      [64.765380859375]    [64.5457763671875]
# 3      [64.765380859375]    [64.5457763671875]
# 4                 [32.0]   [32.16386795043945]
# ..                   ...                   ...
# 487  [48.45000076293945]   [48.36668395996094]
# 488  [52.09000015258789]  [51.969146728515625]
# 489  [50.58000183105469]   [50.47410583496094]
# 490               [43.0]   [42.98319625854492]
# 491  [45.65999984741211]  [45.609073638916016]
#
# [492 rows x 2 columns]
